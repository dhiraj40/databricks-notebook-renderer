# %% [markdown]
# # Databricks-style output demo

# %% [markdown]
# Open this notebook to preview the custom `x-application/custom-json-output` renderer.

# %%
# Example payload for the custom renderer
